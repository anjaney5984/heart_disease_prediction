# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cvd=pd.read_csv(r"C:\Users\Anjaney Deshpande\Desktop\hjghjghjghjghjghjhjghj\CVD.csv")

# %%
cvd.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# ...

# %%
len(cvd.columns)
# Out:
# 19

# %%
cvd=cvd.drop(['Height_(cm)','Weight_(kg)'],axis=1)

# %%
cvd['BMI'].mean().round(2)
# Out:
# 28.63

# %%
cvd['BMI'].median()
# Out:
# 27.44

# %%
plt.figure(figsize=(20, 10))
plt.subplot(2, 3, 1)
sns.countplot(x='Heart_Disease', data=cvd).set_title('Heart Disease')
plt.subplot(2, 3, 2)
sns.countplot(x='Skin_Cancer', data=cvd).set_title('Skin Cancer')
plt.subplot(2, 3, 3)
sns.countplot(x='Other_Cancer', data=cvd).set_title('Other Cancer')
plt.subplot(2, 3, 4)
sns.countplot(x='Depression', data=cvd).set_title('Depression')
plt.subplot(2, 3, 5)
sns.countplot(x='Diabetes', data=cvd).set_title('Diabetes')
plt.xticks(rotation=90)
plt.subplot(2, 3, 6)
sns.countplot(x='Arthritis', data=cvd).set_title('Arthritis')
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# ##These plots give us the number of people/individuals with and without a specific disease
# from the dataset

# %%
sns.countplot(x='Smoking_History',data=cvd)
plt.title('Smoking_History');

# %% [markdown]
# ## The plot shows/displays the count/frequency of smokers and non smokers

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.pie(cvd['Sex'].value_counts(), labels=['Male', 'Female'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Gender')
plt.subplot(1, 3, 2)
sns.countplot(x=cvd['Age_Category'], data=cvd)
plt.xticks(rotation=90)
plt.title('Age Distribution')
plt.subplot(1, 3, 3)
sns.histplot(x=cvd['BMI'], data=cvd, kde=True)
plt.title('Distribution of BMI')
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# # The plots given give us information about the population in the datset most of the patients are male aged above 45 and Bmi plot is right skewed and most patients have bmi over 20

# %% [markdown]
# #Underweight:
#
# #BMI less than 18.5
# Normal Weight:
#
# BMI between 18.5 and 24.9
# Overweight:
#
# BMI between 25 and 29.9
# Obese:
#
# BMI of 30 or greater

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 10))

# Age Distribution vs Heart Disease
plt.subplot(2, 2, 1)
sns.countplot(x='Age_Category', data=cvd, hue='Heart_Disease', palette='winter').set_title('Age Distribution vs Heart Disease')
plt.xticks(rotation=90)

# Gender vs Heart Disease
plt.subplot(2, 2, 2)
sns.countplot(x='Sex', data=cvd, hue='Heart_Disease', palette='winter')

plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
#males are more prone to heart disease and beyond the age of 55 the risk of heart disease increases which
# can be concluded from the graphs

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Exercise',hue='General_Health', data=cvd, palette='winter')
plt.xlabel('Exercise')
plt.ylabel('Frequenct')
plt.title('General Health based on Exercise')
plt.legend(title='General Health')
plt.show()

# %%
# this implies that the patients who tend to do more execrise have very good general health

# %%
sns.countplot(x = 'General_Health', data = cvd, hue  = 'Heart_Disease').set_title('Heart Disease and General Health')
# Out:
# Text(0.5, 1.0, 'Heart Disease and General Health')

# %%
fig = plt.figure(figsize=(20, 10))
plt.subplot(2, 3, 1)
sns.countplot(x='Smoking_History', data=cvd, hue='Heart_Disease').set_title('Smoking History and Heart Disease')
plt.subplot(2, 3, 2)
sns.countplot(x='Skin_Cancer', data=cvd, hue='Heart_Disease').set_title('Skin Cancer and Heart Disease')
plt.subplot(2, 3, 3)
sns.countplot(x='Other_Cancer', data=cvd, hue='Heart_Disease').set_title('Other Cancer and Heart Disease')
plt.subplot(2, 3, 4)
sns.countplot(x='Depression', data=cvd, hue='Heart_Disease').set_title('Depression and Heart Disease')
plt.subplot(2, 3, 5)
sns.countplot(x='Diabetes', data=cvd, hue='Heart_Disease').set_title('Diabetes and Heart Disease')
plt.xticks(rotation=90)
plt.subplot(2, 3, 6)
sns.countplot(x='Arthritis', data=cvd, hue='Heart_Disease').set_title('Arthritis and Heart Disease')
plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
cvd.Sex.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cvd.Sex.replace({'Female':0,'Male':1},inplace=True)

# %%
cvd.General_Health.replace({'Poor':5,'Very Good':2,'Good':3,'Fair':4,'Excellent':1},inplace=True)

# %%
cvd['Checkup'].replace({'Within the past 2 years': 0,'Within the past year': 1,
                            '5 or more years ago': 2,'Within the past 5 years': 3, 'Never': 4}, inplace=True)

# %%
cvd.Exercise.replace({'No':0,'Yes':1},inplace=True)

# %%
cvd.Heart_Disease.replace({'No':0,'Yes':1},inplace=True)

# %%
cvd['Skin_Cancer'].replace({'No':0,'Yes':1},inplace=True)

# %%
cvd.Other_Cancer.replace({'No':0,'Yes':1},inplace=True)

# %%
cvd.Depression.replace({'No':0,'Yes':1},inplace=True)

# %%
cvd['Diabetes'].replace({'No': 0,'Yes': 1,
    'No, pre-diabetes or borderline diabetes': 2,'Yes, but female told only during pregnancy': 3}, inplace=True)

# %%
cvd['Age_Category'].replace({
    '70-74': 0,'60-64': 1,'75-79': 2,'80+': 3,
        '65-69': 4,'50-54': 5, '45-49': 6,'18-24': 7,'30-34': 8, 
    '55-59': 9,'35-39': 10,'40-44': 11,'25-29': 12}, inplace=True)

# %%
cvd.Arthritis.replace({'Yes':1,'No':0},inplace=True)
cvd.Smoking_History.replace({'Yes':1,'No':0},inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
cvd[cvd.select_dtypes(include='object').columns]=cvd[cvd.select_dtypes(include='object').columns].apply(le.fit_transform)

# %%
cvd.corr()
# Out:
#                               General_Health   Checkup  Exercise  \
# General_Health                      1.000000 -0.017496 -0.276096
# Checkup                            -0.017496  1.000000 -0.000231
# Exercise                           -0.276096 -0.000231  1.000000
# Heart_Disease                       0.232503 -0.022594 -0.096347
# Skin_Cancer                         0.047113 -0.031526 -0.003986
# Other_Cancer                        0.145640 -0.029811 -0.054388
# Depression                          0.207587 -0.017351 -0.084729
# Diabetes                            0.213514 -0.032910 -0.107540
# Arthritis                           0.265957 -0.057377 -0.124813
# Sex                                -0.018969  0.062251  0.059344
# Age_Category                       -0.128350  0.074018  0.088446
# BMI                                 0.246499 -0.018360 -0.155756
# Smoking_History                     0.167608  0.020789 -0.093295
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cvd.Sex.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## Heatmap of correlation_Matrix

# %%
plt.figure(figsize=(15,10))
sns.heatmap(cvd.corr().round(2),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
cvd_train,cvd_test=train_test_split(cvd,test_size=0.2)

# %%
# df4 = cvd_train[cvd_train['Heart_Disease'] ==1]
# cvd_train = pd.concat([cvd_train] + [df4] *11, ignore_index=True)

# %%
cvd_train_x = cvd_train.drop(columns=['Heart_Disease'],axis=1)
cvd_train_y = cvd_train['Heart_Disease']
cvd_test_x = cvd_test.drop(columns=['Heart_Disease'],axis=1)
cvd_test_y = cvd_test['Heart_Disease']

# %%
from imblearn.over_sampling import SMOTE    
smote = SMOTE(sampling_strategy='auto', random_state=42)
cvd_train_x_resampled, cvd_train_y_resampled = smote.fit_resample(cvd_train_x, cvd_train_y)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

search_dict = {'criterion': ['gini', 'entropy'], 'max_depth': range(4, 20), 'min_samples_split': [50, 75, 100]}
dtc = DecisionTreeClassifier()
grid = GridSearchCV(dtc, param_grid=search_dict)
grid.fit(cvd_train_x, cvd_train_y)
grid.best_params_

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(criterion='gini',max_depth=19,min_samples_split=50, min_samples_leaf=2)

# %%
dtc.fit(cvd_train_x_resampled, cvd_train_y_resampled)
# Out:
# DecisionTreeClassifier(max_depth=19, min_samples_leaf=2, min_samples_split=50)

# %%
dtc_predicted=dtc.predict(cvd_test_x)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(cvd_test_y,dtc_predicted)
# Out:
# array([[44896, 11829],
#        [ 2716,  2330]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score

# %%
print("Decision_Tree")
print(confusion_matrix(cvd_test_y, dtc_predicted))
print('accuracy_score-->>', accuracy_score(cvd_test_y, dtc_predicted))
print("precision--->", precision_score(cvd_test_y, dtc_predicted))
print('recall-->', recall_score(cvd_test_y, dtc_predicted))

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
import warnings 
warnings.filterwarnings('ignore')

# %%
log.fit(cvd_train_x_resampled, cvd_train_y_resampled)
# Out:
# LogisticRegression()

# %%
pred_log=log.predict(cvd_test_x)

# %%
confusion_matrix(cvd_test_y,pred_log)
#criterion='gini',n_estimators=200,min_samples_split=80
# Out:
# array([[41496, 15229],
#        [ 2302,  2744]], dtype=int64)

# %%
print("Logistic Regression")
print(confusion_matrix(cvd_test_y,pred_log))
print('accuracy_score-->>', accuracy_score(cvd_test_y,pred_log))
print("precision--->", precision_score(cvd_test_y,pred_log))
print('recall-->', recall_score(cvd_test_y,pred_log))

# %%
pred_probabilities = log.predict_proba(cvd_test_x)[:, 1]

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
fpr,tpr,threshold=roc_curve(cvd_test_y,pred_probabilities)
import matplotlib.pyplot as plt
plt.plot(fpr,tpr,marker='*',color='green')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC plot on fpr and tpr');
plt.grid()

# %%
roc_auc_score(cvd_test_y,pred_probabilities)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(criterion='entropy',n_estimators=113,min_samples_split=63,max_depth=8)

# %%
rfc.fit(cvd_train_x_resampled, cvd_train_y_resampled)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8, min_samples_split=63,
#                        n_estimators=113)

# %%
pred_rfc=rfc.predict(cvd_test_x)

# %%
import pickle
pickle.dump(rfc,open(r"C:\Users\Anjaney Deshpande\Desktop\cloudproject\build.pkl",'wb'))

# %%
a=confusion_matrix(cvd_test_y,pred_rfc)
a
# Out:
# array([[41939, 14786],
#        [ 1990,  3056]], dtype=int64)

# %%
cvd_train.columns

# %%
cvd_train.General_Health.value_counts()

# %%
print("Random_Forest")
print(confusion_matrix(cvd_test_y,pred_rfc))
print('accuracy_score-->>', accuracy_score(cvd_test_y,pred_rfc))
print("precision--->", precision_score(cvd_test_y,pred_rfc))
print('recall-->', recall_score(cvd_test_y,pred_rfc))

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
predicted_rfc=rfc.predict_proba(cvd_test_x)[:, 1]

# %%
fpr,tpr,threshold=roc_curve(cvd_test_y,predicted_rfc)
import matplotlib.pyplot as plt
plt.plot(fpr,tpr,marker='*',color='red')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC plot on fpr and tpr for random forest');
plt.grid()

# %%
array([[39236, 17555],
       [  944,  4036]]

# %%
a.diagonal().sum()/a.sum()
#Best Hyperparameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 63, 'n_estimators': 113}

# %% [markdown]
# from sklearn.model_selection import RandomizedSearchCV
# from scipy.stats import randint
# search_dict = {
#     'n_estimators': randint(50, 150),
#     'criterion': ['gini', 'entropy'],
#     'max_depth': randint(4, 9),
#     'min_samples_split': randint(50, 100)
# }
# rfc = RandomForestClassifier()
# random_search = RandomizedSearchCV(rfc, param_distributions=search_dict, n_iter=10, cv=5)
# random_search.fit(cvd_train_x,cvd_train_y)
# print("Best Hyperparameters:", random_search.best_params_)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb=MultinomialNB()

# %%
nb.fit(cvd_train_x_resampled, cvd_train_y_resampled)
# Out:
# MultinomialNB()

# %%
nb_pred=nb.predict(cvd_test_x)

# %%
confusion_matrix(cvd_test_y,nb_pred)
# Out:
# array([[36253, 20472],
#        [ 1510,  3536]], dtype=int64)

# %%
print("Random_Forest")
print(confusion_matrix(cvd_test_y,nb_pred))
print('accuracy_score-->>', accuracy_score(cvd_test_y,nb_pred))
print("precision--->", precision_score(cvd_test_y,nb_pred))
print('recall-->', recall_score(cvd_test_y,nb_pred))

# %%
Decision_Tree
[[43922 12902]
 [ 2143  2804]]
accuracy_score-->> 0.7564391057292257
precision---> 0.17853049789889214
recall--> 0.5668081665655953

Random_Forest
[[36736 20088]
 [ 1319  3628]]
accuracy_score-->> 0.6534457917145586
precision---> 0.1529768932366335
recall--> 0.7333737618758843


Logistic Regression
[[40473 16351]
 [ 1178  3769]]
accuracy_score-->> 0.7162260607728546
precision---> 0.18732604373757455
recall--> 0.7618758843743683



Random_Forest
[[36736 20088]
 [ 1319  3628]]
accuracy_score-->> 0.6534457917145586
precision---> 0.1529768932366335
recall--> 0.7333737618758843

# %%
Random_Forest
[[38923 17740]
 [  870  4238]]

# %%
from sklearn.svm import SVC
29385/60
489.75/60

# %%
import timeit
from sklearn.svm import SVC
svc=SVC(kernel='poly',degree=4)
start_time = timeit.default_timer()
svc.fit(cvd_train_x, cvd_train_y)
stop_time = timeit.default_timer()
print("Total Time:", stop_time - start_time)

# %%
svc_pred=svc.predict(cvd_test_x)

# %%
confusion_matrix(cvd_test_y,pred_svc)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.subplot(2, 2, 1)
sns.heatmap(confusion_matrix(cvd_test_y,dtc_predicted), annot=True, fmt='d', cmap='turbo').set_title('Decision Tree Classifier')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.subplot(2, 2, 2)
sns.heatmap(confusion_matrix(cvd_test_y, pred_log), annot=True, fmt='d',cmap='turbo').set_title('Logistic Regression')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.subplot(2, 2, 3)
sns.heatmap(confusion_matrix(cvd_test_y, pred_rfc), annot=True, fmt='d',cmap='turbo').set_title('Random Forest')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.subplot(2, 2, 4)
sns.heatmap(confusion_matrix(cvd_test_y,nb_pred), annot=True, fmt='d',cmap='turbo').set_title('Naive Bayes')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.tight_layout()
plt.show()

# %%
# Random_Forest
# 0 -->>[[38923 17740]
# 1---->[  870  4238]]
# random forest 82 % correct predictions for class 1 &  70 percent correct predictions for class 0
# aucroc score random forest--->>84%
# logistics regression 71 % coreect prediction for class 0  and 76 for class 1
# naive bayes  64 % correct for class 0 and 76 % correct prediction for class 1
# decusion tree 77% correct for class 0 and 54 percent correct prediction for class 1

# %%
import pandas as pd

# Define the data
data = {
    'Model': ['Decision_Tree', 'Random_Forest', 'Logistic_Regression', 'Random_Forest'],
    'Accuracy': [0.7564391057292257, 0.6534457917145586, 0.7162260607728546, 0.6534457917145586],
    'Precision': [0.17853049789889214, 0.1529768932366335, 0.18732604373757455, 0.1529768932366335],
    'Recall': [0.5668081665655953, 0.7333737618758843, 0.7618758843743683, 0.7333737618758843]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
df
# Out:
#                  Model  Accuracy  Precision    Recall
# 0        Decision_Tree  0.756439   0.178530  0.566808
# 1        Random_Forest  0.653446   0.152977  0.733374
# 2  Logistic_Regression  0.716226   0.187326  0.761876
# 3        Random_Forest  0.653446   0.152977  0.733374

# %%
# Random Forest:
# - For Class 0: Achieves a commendable 70% accuracy, indicating strong predictive power.
# - For Class 1: Demonstrates impressive accuracy at 82%, showcasing robust classification ability.
# - AUC-ROC Score: An impressive 84%, underlining its effectiveness in distinguishing between classes.

# Logistic Regression:
# - Class 0: Displays a respectable 71% accuracy, suggesting reliable performance in identifying negative instances.
# - Class 1: Shows a promising accuracy rate of 76%, indicating its capability in recognizing positive instances.

# Naive Bayes:
# - Class 0: Attains a noteworthy 64% accuracy, implying satisfactory performance in identifying negative instances.
# - Class 1: Exhibits a commendable 76% accuracy, indicating strong predictive power in recognizing positive instances.

# Decision Tree:
# - Class 0: Achieves a solid 77% accuracy, signifying good performance in identifying negative instances.
# - Class 1: Indicates a moderate accuracy rate of 54%, suggesting room for improvement in recognizing positive instances.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Define custom colormap
cmap = sns.light_palette("navy", as_cmap=True)

plt.subplot(2, 2, 1)
sns.heatmap(confusion_matrix(cvd_test_y, dtc_predicted), annot=True, fmt='d', cmap=cmap).set_title('Decision Tree Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(2, 2, 2)
sns.heatmap(confusion_matrix(cvd_test_y, pred_log), annot=True, fmt='d', cmap=cmap).set_title('Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(2, 2, 3)
sns.heatmap(confusion_matrix(cvd_test_y, pred_rfc), annot=True, fmt='d', cmap=cmap).set_title('Random Forest')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(2, 2, 4)
sns.heatmap(confusion_matrix(cvd_test_y, nb_pred), annot=True, fmt='d', cmap=cmap).set_title('Naive Bayes')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Define Solarized Dark background color
solarized_dark = '#002b36'

# Set the figure facecolor to Solarized Dark
plt.figure(facecolor=solarized_dark)

plt.subplot(2, 2, 1)
sns.heatmap(confusion_matrix(cvd_test_y, dtc_predicted), annot=True, fmt='d', cmap='turbo').set_title('Decision Tree Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(2, 2, 2)
sns.heatmap(confusion_matrix(cvd_test_y, pred_log), annot=True, fmt='d', cmap='turbo').set_title('Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(2, 2, 3)
sns.heatmap(confusion_matrix(cvd_test_y, pred_rfc), annot=True, fmt='d', cmap='turbo').set_title('Random Forest')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(2, 2, 4)
sns.heatmap(confusion_matrix(cvd_test_y, nb_pred), annot=True, fmt='d', cmap='turbo').set_title('Naive Bayes')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()
